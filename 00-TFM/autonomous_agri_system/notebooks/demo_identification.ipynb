# %% [markdown]
# # Identification Demo
# Build DeepLabV3+ model and run a synthetic forward pass.

# %%
import torch
from identification.deeplabv3plus import build_deeplabv3plus

model = build_deeplabv3plus(num_classes=5, pretrained=False)
x = torch.randn(1,3,512,512)
y = model(x)
if isinstance(y, dict):
    y = y['out']
y.shape
